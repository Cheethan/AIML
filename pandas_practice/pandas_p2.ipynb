# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("IPL Matches 2008-2020.csv")
df.head() # First 5 rows of df
df.tail(10) # Last 5 or n rows of df
# Out:
#           id       city        date player_of_match  \
# 806  1216542      Dubai  2020-10-08     JM Bairstow
# 807  1216543      Dubai  2020-10-14        A Nortje
# 808  1216544      Dubai  2020-10-25      RD Gaikwad
# 809  1216545  Abu Dhabi  2020-09-26    Shubman Gill
# 810  1216546      Dubai  2020-10-20        S Dhawan
# 811  1216547      Dubai  2020-09-28  AB de Villiers
# 812  1237177      Dubai  2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181      Dubai  2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 806  Dubai International Cricket Stadium              0
# 807  Dubai International Cricket Stadium              0
# 808  Dubai International Cricket Stadium              0
# 809                 Sheikh Zayed Stadium              0
# 810  Dubai International Cricket Stadium              0
# ...

# %%
df.shape
# Out:
# (816, 17)

# %%
df.info() # object -> most likely it's a string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df["id"] = df["id"].astype(np.int32) # decreased memory useage by 3.2 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int32
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df["umpire1"] = df["umpire1"].astype(str)
type(df["umpire1"])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int32
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
df.describe() # works on integral value cols
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
type(df[["city","date"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:5:2,0::2] # fetches row and cols, supports fancy indexing too
# Out:
#        id        date                  venue                        team1  \
# 0  335982  2008-04-18  M Chinnaswamy Stadium  Royal Challengers Bangalore
# 2  335984  2008-04-19       Feroz Shah Kotla             Delhi Daredevils
# 4  335986  2008-04-20           Eden Gardens        Kolkata Knight Riders
#
#                    toss_winner                 winner  result_margin method  \
# 0  Royal Challengers Bangalore  Kolkata Knight Riders          140.0    NaN
# 2             Rajasthan Royals       Delhi Daredevils            9.0    NaN
# 4              Deccan Chargers  Kolkata Knight Riders            5.0    NaN
#
#           umpire2
# 0     RE Koertzen
# 2  GA Pratapkumar
# 4     K Hariharan

# %%
filter_DC = df["toss_winner"] == "Deccan Chargers"

# %%
df[filter_DC] # Toss winners only DC
# Out:
#          id            city        date  player_of_match  \
# 4    335986         Kolkata  2008-04-20        DJ Hussey
# 6    335988       Hyderabad  2008-04-22         V Sehwag
# 12   335994          Mumbai  2008-04-27     AC Gilchrist
# 20   336002       Hyderabad  2008-05-25    R Vinay Kumar
# 25   336007         Chennai  2008-05-06     AC Gilchrist
# 38   336020           Delhi  2008-05-15         A Mishra
# 42   336024       Hyderabad  2008-05-18         DJ Bravo
# 51   336034       Bangalore  2008-05-03          P Kumar
# 54   336037       Hyderabad  2008-05-27         SK Raina
# 64   392188       Cape Town  2009-04-22     AC Gilchrist
# 68   392192          Durban  2009-04-25          PP Ojha
# 71   392196          Durban  2009-04-27         HH Gibbs
# 80   392205  Port Elizabeth  2009-05-02        YK Pathan
# 87   392212       Centurion  2009-05-06        RG Sharma
# 95   392220       Kimberley  2009-05-11         DR Smith
# ...

# %%
filter_Hyd = df["city"] == "Hyderabad"

# %%
df[filter_Hyd]
# Out:
#           id       city        date player_of_match  \
# 6     335988  Hyderabad  2008-04-22        V Sehwag
# 8     335990  Hyderabad  2008-04-24       YK Pathan
# 17    335999  Hyderabad  2008-05-01        SE Marsh
# 20    336002  Hyderabad  2008-05-25   R Vinay Kumar
# 32    336014  Hyderabad  2008-05-11      SC Ganguly
# ..       ...        ...         ...             ...
# 725  1178405  Hyderabad  2019-04-14        KMA Paul
# 728  1178408  Hyderabad  2019-04-17       DA Warner
# 733  1178413  Hyderabad  2019-04-21        KK Ahmed
# 743  1178423  Hyderabad  2019-04-29       DA Warner
# 755  1181768  Hyderabad  2019-05-12       JJ Bumrah
#
#                                          venue  neutral_venue  \
# 6    Rajiv Gandhi International Stadium, Uppal              0
# 8    Rajiv Gandhi International Stadium, Uppal              0
# 17   Rajiv Gandhi International Stadium, Uppal              0
# 20   Rajiv Gandhi International Stadium, Uppal              0
# ...

# %%
df[filter_Hyd & filter_DC].shape[0] # Tells us how may tosses did Deccan Chargers win in Hyderabad
# Out:
# 9

# %% [markdown]
# # Value counts

# %%
# Works on catagorical data and Series data type

df["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
# when we check total matches of DC, some time it's considered as team1 and other times as team2 - find total matches played

team1 = df["team1"].value_counts()
team2 = df["team2"].value_counts()

print(team1["Deccan Chargers"] + team2["Deccan Chargers"])
# Out:
# 75

# %%
team1.sort_values(ascending=False,inplace = True) # By default it gives sords in ascending, inplace - makes the changes permanent

# %%
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df.drop_duplicates(subset=["city"]).shape  # deletes duplicate occurences - (subset,keep,inplace)
# Out:
# (33, 17)

# %%
based_on_toss = df.groupby("toss_decision") # helps to group catagorical data

# %%
len(based_on_toss) # either win/loose i.e bat or feild 
based_on_toss.size() # .last(), .first(), .groups() -> returns dict
based_on_toss.get_group("bat") # give data of a pircticular group
# Out:
#           id        city        date player_of_match  \
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# 5     335987      Jaipur  2008-04-21       SR Watson
# ..       ...         ...         ...             ...
# 808  1216544       Dubai  2020-10-25      RD Gaikwad
# 809  1216545   Abu Dhabi  2020-09-26    Shubman Gill
# 810  1216546       Dubai  2020-10-20        S Dhawan
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# 4                                  Eden Gardens              0
# ...

# %%
player_df = pd.read_csv("deliveries.csv")

# %%
batsman = player_df.groupby("batsman")

# %%
player_df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
total_runs = batsman.sum(["batsman_runs"])

# %%
total_runs_series = total_runs["batsman_runs"]

# %%
total_runs_series.sort_values(ascending=False)
# Out:
# batsman
# SK Raina        4548
# V Kohli         4423
# RG Sharma       4207
# G Gambhir       4132
# DA Warner       4014
#                 ...
# RR Bhatkal         0
# M Ashwin           0
# Abdur Razzak       0
# IC Pandey          0
# Sunny Gupta        0
# Name: batsman_runs, Length: 461, dtype: int64

# %%
# Q. Top number of 4's
    

mask = player_df["batsman_runs"] == 4

# %%
only_four = player_df[mask]

# %%
four_grp = only_four.groupby("batsman")
four_grp.size()
# Out:
# batsman
# A Ashish Reddy     16
# A Chopra            7
# A Choudhary         1
# A Flintoff          5
# A Kumble            3
#                  ...
# YK Pathan         240
# YV Takawale        26
# Yashpal Singh       5
# Yuvraj Singh      205
# Z Khan             11
# Length: 368, dtype: int64

# %%
four_grp["batsman_runs"].count()
# Out:
# batsman
# A Ashish Reddy     16
# A Chopra            7
# A Choudhary         1
# A Flintoff          5
# A Kumble            3
#                  ...
# YK Pathan         240
# YV Takawale        26
# Yashpal Singh       5
# Yuvraj Singh      205
# Z Khan             11
# Name: batsman_runs, Length: 368, dtype: int64

# %%
player_df = pd.read_csv("deliveries.csv")

# %%
player_df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
mask_dw = player_df["batsman"] == "DA Warner"

# %%
mask_dw
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459    False
# Name: batsman, Length: 150460, dtype: bool

# %%
df_dw = player_df[mask_dw]
dw_grp = df_dw.groupby("bowling_team")

# %%
top_runs_dw = dw_grp["total_runs"]

# %%
top_runs_dw.sum()
# Out:
# bowling_team
# Chennai Super Kings            353
# Deccan Chargers                243
# Delhi Daredevils               277
# Gujarat Lions                  349
# Kings XI Punjab                697
# Kochi Tuskers Kerala            18
# Kolkata Knight Riders          709
# Mumbai Indians                 492
# Pune Warriors                  123
# Rajasthan Royals               242
# Rising Pune Supergiant          87
# Rising Pune Supergiants         12
# Royal Challengers Bangalore    602
# Sunrisers Hyderabad              9
# Name: total_runs, dtype: int64

# %%
# Merge 
# df1.merge(df2,left_on = "df1_id_col",right_on = "df2_col_id")
# .reset_index() - used to convert a non-df to df with index
# .drop_duplicates(subset = "col",keep="first/last");
